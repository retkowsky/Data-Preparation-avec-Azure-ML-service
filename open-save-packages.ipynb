# %% [markdown]
# # Opening and Saving Packages
# Copyright (c) Microsoft Corporation. All rights reserved.<br>
# Licensed under the MIT License.

# %% [markdown]
# Once you have built a dataflow, you can save it as a package to a DPREP file. This persists all of the information in your dataflow including steps you've added, examples and programs from by-example steps, computed aggregations, etc.
#
# You can also open DPREP files to access any dataflows in those packages.
#
# A DPREP package (and DPREP file) can contain multiple dataflows, and each dataflow in a package must have a unique name.

# %% [markdown]
# ## Open
#
# Use the `open()` method of the Package class to load existing DPREP files. You can then index into the Package to access a particular dataflow.

# %%
import os
package_path = os.path.join(os.getcwd(), 'data', 'crime0-10.dprep')

# %%
from azureml.dataprep.api.package import Package

# %%
p = Package.open(package_path)
t = p['crime0-10']
h = t.head(100)
h
# Out:
#            ID Case Number                Date                     Block  \
# 0  10140490.0    HY329907 2015-07-05 23:50:00       050XX N NEWLAND AVE
# 1  10139776.0    HY329265 2015-07-05 23:30:00         011XX W MORSE AVE
# 2  10140270.0    HY329253 2015-07-05 23:20:00         121XX S FRONT AVE
# 3  10139885.0    HY329308 2015-07-05 23:19:00       051XX W DIVISION ST
# 4  10140379.0    HY329556 2015-07-05 23:00:00           012XX W LAKE ST
# 5  10140868.0    HY330421 2015-07-05 22:54:00         118XX S PEORIA ST
# 6  10139762.0    HY329232 2015-07-05 22:42:00           026XX W 37TH PL
# 7  10139722.0    HY329228 2015-07-05 22:30:00  016XX S CENTRAL PARK AVE
# 8  10139774.0    HY329209 2015-07-05 22:15:00       048XX N ASHLAND AVE
# 9  10139697.0    HY329177 2015-07-05 22:10:00      058XX S ARTESIAN AVE
#
#      IUCR         Primary Type                   Description  \
# 0   820.0                THEFT                $500 AND UNDER
# 1   460.0              BATTERY                        SIMPLE
# 2   486.0              BATTERY       DOMESTIC BATTERY SIMPLE
# 3   610.0             BURGLARY                FORCIBLE ENTRY
# 4   930.0  MOTOR VEHICLE THEFT    THEFT/RECOVERY: AUTOMOBILE
# 5  1320.0      CRIMINAL DAMAGE                    TO VEHICLE
# 6  1020.0                ARSON                       BY FIRE
# 7  1811.0            NARCOTICS  POSS: CANNABIS 30GMS OR LESS
# 8  1310.0      CRIMINAL DAMAGE                   TO PROPERTY
# 9  1320.0      CRIMINAL DAMAGE                    TO VEHICLE
#
#      Location Description  Arrest  Domestic              ...                \
# 0                  STREET   False     False              ...
# 1                  STREET   False      True              ...
# 2                  STREET   False      True              ...
# 3      SMALL RETAIL STORE   False     False              ...
# 4                  STREET   False     False              ...
# 5  VEHICLE NON-COMMERCIAL   False     False              ...
# 6         VACANT LOT/LAND   False     False              ...
# 7                   ALLEY    True     False              ...
# 8               APARTMENT   False     False              ...
# 9                   ALLEY   False     False              ...
#
#    Ward  Community Area  FBI Code  X Coordinate Y Coordinate    Year  \
# 0  41.0            10.0        06     1129230.0    1933315.0  2015.0
# 1  49.0             1.0       08B     1167370.0    1946271.0  2015.0
# 2   9.0            53.0       08B           NaN          NaN  2015.0
# 3  37.0            25.0        05     1141721.0    1907465.0  2015.0
# 4  27.0            28.0        07     1168413.0    1901632.0  2015.0
# 5  34.0            53.0        14     1172409.0    1826485.0  2015.0
# 6  12.0            58.0        09     1159436.0    1879658.0  2015.0
# 7  24.0            29.0        18     1152687.0    1891389.0  2015.0
# 8  46.0             3.0        14     1164821.0    1932394.0  2015.0
# 9  16.0            63.0        14     1160997.0    1865851.0  2015.0
#
#            Updated On   Latitude  Longitude                       Location
# 0 2015-07-12 12:42:46  41.973309 -87.800175  (41.973309466, -87.800174996)
# 1 2015-07-12 12:42:46  42.008124 -87.659550   (42.008124017, -87.65955018)
# 2 2015-07-12 12:42:46        NaN        NaN
# 3 2015-07-12 12:42:46  41.902152 -87.754883  (41.902152027, -87.754883404)
# 4 2015-07-12 12:42:46  41.885610 -87.657009  (41.885610142, -87.657008701)
# 5 2015-07-12 12:42:46  41.679311 -87.644545    (41.6793109, -87.644545209)
# 6 2015-07-12 12:42:46  41.825501 -87.690578  (41.825500607, -87.690578042)
# 7 2015-07-12 12:42:46  41.857828 -87.715029  (41.857827814, -87.715028789)
# 8 2015-07-12 12:42:46  41.970100 -87.669324  (41.970099796, -87.669324377)
# 9 2015-07-12 12:42:46  41.787580 -87.685233  (41.787580282, -87.685233078)
#
# [10 rows x 22 columns]

# %% [markdown]
# ## Edit
#
# After a dataflow is loaded, it can be further edited as needed. In this example, a filter is added.

# %%
from azureml.dataprep.api.expressions import col

# %%
t = t.filter(col('Description') != 'SIMPLE')
h = t.head(100)
h
# Out:
#            ID Case Number                Date                     Block  \
# 0  10140490.0    HY329907 2015-07-05 23:50:00       050XX N NEWLAND AVE
# 1  10140270.0    HY329253 2015-07-05 23:20:00         121XX S FRONT AVE
# 2  10139885.0    HY329308 2015-07-05 23:19:00       051XX W DIVISION ST
# 3  10140379.0    HY329556 2015-07-05 23:00:00           012XX W LAKE ST
# 4  10140868.0    HY330421 2015-07-05 22:54:00         118XX S PEORIA ST
# 5  10139762.0    HY329232 2015-07-05 22:42:00           026XX W 37TH PL
# 6  10139722.0    HY329228 2015-07-05 22:30:00  016XX S CENTRAL PARK AVE
# 7  10139774.0    HY329209 2015-07-05 22:15:00       048XX N ASHLAND AVE
# 8  10139697.0    HY329177 2015-07-05 22:10:00      058XX S ARTESIAN AVE
#
#      IUCR         Primary Type                   Description  \
# 0   820.0                THEFT                $500 AND UNDER
# 1   486.0              BATTERY       DOMESTIC BATTERY SIMPLE
# 2   610.0             BURGLARY                FORCIBLE ENTRY
# 3   930.0  MOTOR VEHICLE THEFT    THEFT/RECOVERY: AUTOMOBILE
# 4  1320.0      CRIMINAL DAMAGE                    TO VEHICLE
# 5  1020.0                ARSON                       BY FIRE
# 6  1811.0            NARCOTICS  POSS: CANNABIS 30GMS OR LESS
# 7  1310.0      CRIMINAL DAMAGE                   TO PROPERTY
# 8  1320.0      CRIMINAL DAMAGE                    TO VEHICLE
#
#      Location Description  Arrest  Domestic              ...                \
# 0                  STREET   False     False              ...
# 1                  STREET   False      True              ...
# 2      SMALL RETAIL STORE   False     False              ...
# 3                  STREET   False     False              ...
# 4  VEHICLE NON-COMMERCIAL   False     False              ...
# 5         VACANT LOT/LAND   False     False              ...
# 6                   ALLEY    True     False              ...
# 7               APARTMENT   False     False              ...
# 8                   ALLEY   False     False              ...
#
#    Ward  Community Area  FBI Code  X Coordinate Y Coordinate    Year  \
# 0  41.0            10.0        06     1129230.0    1933315.0  2015.0
# 1   9.0            53.0       08B           NaN          NaN  2015.0
# 2  37.0            25.0        05     1141721.0    1907465.0  2015.0
# 3  27.0            28.0        07     1168413.0    1901632.0  2015.0
# 4  34.0            53.0        14     1172409.0    1826485.0  2015.0
# 5  12.0            58.0        09     1159436.0    1879658.0  2015.0
# 6  24.0            29.0        18     1152687.0    1891389.0  2015.0
# 7  46.0             3.0        14     1164821.0    1932394.0  2015.0
# 8  16.0            63.0        14     1160997.0    1865851.0  2015.0
#
#            Updated On   Latitude  Longitude                       Location
# 0 2015-07-12 12:42:46  41.973309 -87.800175  (41.973309466, -87.800174996)
# 1 2015-07-12 12:42:46        NaN        NaN
# 2 2015-07-12 12:42:46  41.902152 -87.754883  (41.902152027, -87.754883404)
# 3 2015-07-12 12:42:46  41.885610 -87.657009  (41.885610142, -87.657008701)
# 4 2015-07-12 12:42:46  41.679311 -87.644545    (41.6793109, -87.644545209)
# 5 2015-07-12 12:42:46  41.825501 -87.690578  (41.825500607, -87.690578042)
# 6 2015-07-12 12:42:46  41.857828 -87.715029  (41.857827814, -87.715028789)
# 7 2015-07-12 12:42:46  41.970100 -87.669324  (41.970099796, -87.669324377)
# 8 2015-07-12 12:42:46  41.787580 -87.685233  (41.787580282, -87.685233078)
#
# [9 rows x 22 columns]

# %% [markdown]
# ## Save
#
# Use the `save()` method of the Package class to write out the DPREP file. To create a Package, pass it a list of dataflow objects.

# %%
import tempfile
temp_dir = tempfile._get_default_tempdir()
temp_file_name = next(tempfile._get_candidate_names())
temp_package_path = os.path.join(temp_dir, temp_file_name + '.dprep')

# %%
t = t.set_name('New-Crime')
p_to_save = Package([t])
p_to_save = p_to_save.save(temp_package_path)

# %% [markdown]
# ## Round-trip
#
# This illustrates the ability to load the edited dataflow back in and use it, in this case to get a Pandas dataframe.

# %%
p_to_open = Package.open(temp_package_path)
t_to_open = p_to_open['New-Crime']
df = t_to_open.to_pandas_dataframe()
df
# Out:
#            ID Case Number                Date                     Block  \
# 0  10140490.0    HY329907 2015-07-05 23:50:00       050XX N NEWLAND AVE
# 1  10140270.0    HY329253 2015-07-05 23:20:00         121XX S FRONT AVE
# 2  10139885.0    HY329308 2015-07-05 23:19:00       051XX W DIVISION ST
# 3  10140379.0    HY329556 2015-07-05 23:00:00           012XX W LAKE ST
# 4  10140868.0    HY330421 2015-07-05 22:54:00         118XX S PEORIA ST
# 5  10139762.0    HY329232 2015-07-05 22:42:00           026XX W 37TH PL
# 6  10139722.0    HY329228 2015-07-05 22:30:00  016XX S CENTRAL PARK AVE
# 7  10139774.0    HY329209 2015-07-05 22:15:00       048XX N ASHLAND AVE
# 8  10139697.0    HY329177 2015-07-05 22:10:00      058XX S ARTESIAN AVE
#
#      IUCR         Primary Type                   Description  \
# 0   820.0                THEFT                $500 AND UNDER
# 1   486.0              BATTERY       DOMESTIC BATTERY SIMPLE
# 2   610.0             BURGLARY                FORCIBLE ENTRY
# 3   930.0  MOTOR VEHICLE THEFT    THEFT/RECOVERY: AUTOMOBILE
# 4  1320.0      CRIMINAL DAMAGE                    TO VEHICLE
# 5  1020.0                ARSON                       BY FIRE
# 6  1811.0            NARCOTICS  POSS: CANNABIS 30GMS OR LESS
# 7  1310.0      CRIMINAL DAMAGE                   TO PROPERTY
# 8  1320.0      CRIMINAL DAMAGE                    TO VEHICLE
#
#      Location Description  Arrest  Domestic              ...                \
# 0                  STREET   False     False              ...
# 1                  STREET   False      True              ...
# 2      SMALL RETAIL STORE   False     False              ...
# 3                  STREET   False     False              ...
# 4  VEHICLE NON-COMMERCIAL   False     False              ...
# 5         VACANT LOT/LAND   False     False              ...
# 6                   ALLEY    True     False              ...
# 7               APARTMENT   False     False              ...
# 8                   ALLEY   False     False              ...
#
#    Ward  Community Area  FBI Code  X Coordinate Y Coordinate    Year  \
# 0  41.0            10.0        06     1129230.0    1933315.0  2015.0
# 1   9.0            53.0       08B           NaN          NaN  2015.0
# 2  37.0            25.0        05     1141721.0    1907465.0  2015.0
# 3  27.0            28.0        07     1168413.0    1901632.0  2015.0
# 4  34.0            53.0        14     1172409.0    1826485.0  2015.0
# 5  12.0            58.0        09     1159436.0    1879658.0  2015.0
# 6  24.0            29.0        18     1152687.0    1891389.0  2015.0
# 7  46.0             3.0        14     1164821.0    1932394.0  2015.0
# 8  16.0            63.0        14     1160997.0    1865851.0  2015.0
#
#            Updated On   Latitude  Longitude                       Location
# 0 2015-07-12 12:42:46  41.973309 -87.800175  (41.973309466, -87.800174996)
# 1 2015-07-12 12:42:46        NaN        NaN
# 2 2015-07-12 12:42:46  41.902152 -87.754883  (41.902152027, -87.754883404)
# 3 2015-07-12 12:42:46  41.885610 -87.657009  (41.885610142, -87.657008701)
# 4 2015-07-12 12:42:46  41.679311 -87.644545    (41.6793109, -87.644545209)
# 5 2015-07-12 12:42:46  41.825501 -87.690578  (41.825500607, -87.690578042)
# 6 2015-07-12 12:42:46  41.857828 -87.715029  (41.857827814, -87.715028789)
# 7 2015-07-12 12:42:46  41.970100 -87.669324  (41.970099796, -87.669324377)
# 8 2015-07-12 12:42:46  41.787580 -87.685233  (41.787580282, -87.685233078)
#
# [9 rows x 22 columns]

# %%
if os.path.isfile(temp_package_path):
    os.remove(temp_package_path)
