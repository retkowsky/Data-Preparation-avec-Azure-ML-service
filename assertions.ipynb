# %% [markdown]
# # Assertions
# Copyright (c) Microsoft Corporation. All rights reserved.<br>
# Licensed under the MIT License.

# %% [markdown]
# Frequently, the data we work with while cleaning and preparing data is just a subset of the total data we will need to work with in production. It is also common to be working on a snapshot of a live dataset that is continuously updated and augmented.
#
# In these cases, some of the assumptions we make as part of our cleaning might turn out to be false. Columns that originally only contained numbers within a certain range might actually contain a wider range of values in later executions. These errors often result in either broken pipelines or bad data.
#
# AzureML DataPrep supports creating assertions on data, which are evaluated as the pipeline is executed. These assertions enable us to verify that our assumptions on the data continue to be accurate and, when not, to handle failures in a clean way.

# %% [markdown]
# To demonstrate, we will load a dataset and then add some assertions based on what we can see in the first few rows.

# %%
import sys
sys.version
# Out:
# '3.6.6 |Anaconda, Inc.| (default, Jun 28 2018, 17:14:51) \n[GCC 7.2.0]'

# %%
import azureml

# %%
from azureml.dataprep import smart_read_file

df = smart_read_file('./data/crime0-10.csv')
df.get_profile()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Function smart_read_file is deprecated. Use auto_read_file instead.
#   app.launch_new_instance()
# ColumnProfile
#     name: ID
#     type: FieldType.DECIMAL
#
#     min: 10139697.0
#     max: 10140868.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 10139697.0
#            1%: 10139709.5
#            5%: 10139697.0
#           25%: 10139762.0
#           50%: 10139830.5
#           75%: 10140379.0
#           95%: 10140868.0
#           99%: 10140868.0
#         99.9%: 10140868.0
#
#     mean: 10140062.299999999
#     std: 409.80565854762824
#     variance: 167940.67777765525
#     skewness: 0.6883524570707924
#     kurtosis: -1.1536428984684086
#
# ColumnProfile
#     name: Case Number
#     type: FieldType.STRING
#
#     min: HY329177
#     max: HY330421
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Date
#     type: FieldType.STRING
#
#     min: 07/05/2015 10:10:00 PM
#     max: 07/05/2015 11:50:00 PM
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Block
#     type: FieldType.STRING
#
#     min: 011XX W MORSE AVE
#     max: 121XX S FRONT AVE
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: IUCR
#     type: FieldType.DECIMAL
#
#     min: 460.0
#     max: 1811.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 460.0
#            1%: 473.0
#            5%: 460.0
#           25%: 610.0
#           50%: 975.0
#           75%: 1320.0
#           95%: 1811.0
#           99%: 1811.0
#         99.9%: 1811.0
#
#     mean: 1008.6999999999999
#     std: 435.0555647781608
#     variance: 189273.34444444446
#     skewness: 0.273880231989922
#     kurtosis: -1.2324333429507028
#
# ColumnProfile
#     name: Primary Type
#     type: FieldType.STRING
#
#     min: ARSON
#     max: THEFT
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Description
#     type: FieldType.STRING
#
#     min: $500 AND UNDER
#     max: TO VEHICLE
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Location Description
#     type: FieldType.STRING
#
#     min: ALLEY
#     max: VEHICLE NON-COMMERCIAL
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Arrest
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Domestic
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Beat
#     type: FieldType.DECIMAL
#
#     min: 524.0
#     max: 2431.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 524.0
#            1%: 528.0
#            5%: 524.0
#           25%: 824.0
#           50%: 1118.0
#           75%: 1613.0
#           95%: 2431.0
#           99%: 2431.0
#         99.9%: 2431.0
#
#     mean: 1263.3999999999999
#     std: 633.1475516988297
#     variance: 400875.8222222222
#     skewness: 0.4606773427916479
#     kurtosis: -1.2148110554360347
#
# ColumnProfile
#     name: District
#     type: FieldType.DECIMAL
#
#     min: 5.0
#     max: 24.0
#     count: 10.0
#     missing_count: 1.0
#     not_missing_count: 9.0
#     percent_missing: 0.1
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 5.0
#            1%: 6.2
#            5%: 5.0
#           25%: 8.75
#           50%: 12.0
#           75%: 17.0
#           95%: 24.0
#           99%: 24.0
#         99.9%: 24.0
#
#     mean: 13.222222222222221
#     std: 6.098724821177329
#     variance: 37.19444444444444
#     skewness: 0.3828128522782998
#     kurtosis: -1.2800261778487807
#
# ColumnProfile
#     name: Ward
#     type: FieldType.DECIMAL
#
#     min: 9.0
#     max: 49.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 9.0
#            1%: 10.5
#            5%: 9.0
#           25%: 16.0
#           50%: 30.5
#           75%: 41.0
#           95%: 49.0
#           99%: 49.0
#         99.9%: 49.0
#
#     mean: 29.5
#     std: 14.167647024902275
#     variance: 200.72222222222226
#     skewness: -0.09410071523495527
#     kurtosis: -1.648918863969479
#
# ColumnProfile
#     name: Community Area
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 63.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1.0
#            1%: 2.0
#            5%: 1.0
#           25%: 10.0
#           50%: 28.5
#           75%: 53.0
#           95%: 63.0
#           99%: 63.0
#         99.9%: 63.0
#
#     mean: 32.3
#     std: 23.281132083966863
#     variance: 542.0111111111112
#     skewness: -0.02982541942615151
#     kurtosis: -1.7612546753590468
#
# ColumnProfile
#     name: FBI Code
#     type: FieldType.STRING
#
#     min: 05
#     max: 18
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: X Coordinate
#     type: FieldType.DECIMAL
#
#     min: 1129230.0
#     max: 1172409.0
#     count: 10.0
#     missing_count: 1.0
#     not_missing_count: 9.0
#     percent_missing: 0.1
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1129230.0
#            1%: 1134226.4
#            5%: 1129230.0
#           25%: 1149945.5
#           50%: 1160997.0
#           75%: 1167630.75
#           95%: 1172409.0
#           99%: 1172409.0
#         99.9%: 1172409.0
#
#     mean: 1157453.7777777778
#     std: 14052.038898125935
#     variance: 197459797.19444433
#     skewness: -0.8167695241975886
#     kurtosis: -0.7955776867289264
#
# ColumnProfile
#     name: Y Coordinate
#     type: FieldType.DECIMAL
#
#     min: 1826485.0
#     max: 1946271.0
#     count: 10.0
#     missing_count: 1.0
#     not_missing_count: 9.0
#     percent_missing: 0.1
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1826485.0
#            1%: 1842231.4
#            5%: 1826485.0
#           25%: 1876206.25
#           50%: 1901632.0
#           75%: 1932624.25
#           95%: 1946271.0
#           99%: 1946271.0
#         99.9%: 1946271.0
#
#     mean: 1898273.3333333333
#     std: 37733.23942825477
#     variance: 1423797357.7500005
#     skewness: -0.4481360090688111
#     kurtosis: -1.028783137057662
#
# ColumnProfile
#     name: Year
#     type: FieldType.DECIMAL
#
#     min: 2015.0
#     max: 2015.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 2015.0
#            1%: 2015.0
#            5%: 2015.0
#           25%: 2015.0
#           50%: 2015.0
#           75%: 2015.0
#           95%: 2015.0
#           99%: 2015.0
#         99.9%: 2015.0
#
#     mean: 2015.0
#     std: 0.0
#     variance: 0.0
#     skewness: nan
#     kurtosis: nan
#
# ColumnProfile
#     name: Updated On
#     type: FieldType.STRING
#
#     min: 07/12/2015 12:42:46 PM
#     max: 07/12/2015 12:42:46 PM
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Latitude
#     type: FieldType.DECIMAL
#
#     min: 41.6793109
#     max: 42.008124017
#     count: 10.0
#     missing_count: 1.0
#     not_missing_count: 9.0
#     percent_missing: 0.1
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 41.6793109
#            1%: 41.722618652799994
#            5%: 41.6793109
#           25%: 41.81602052575
#           50%: 41.885610142
#           75%: 41.9709022135
#           95%: 42.008124017
#           99%: 42.008124017
#         99.9%: 42.008124017
#
#     mean: 41.87661278344444
#     std: 0.10364520556300645
#     variance: 0.010742328636197864
#     skewness: -0.4504133511718018
#     kurtosis: -1.027551479452864
#
# ColumnProfile
#     name: Longitude
#     type: FieldType.DECIMAL
#
#     min: -87.800174996
#     max: -87.644545209
#     count: 10.0
#     missing_count: 1.0
#     not_missing_count: 9.0
#     percent_missing: 0.1
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: -87.800174996
#            1%: -87.7820583592
#            5%: -87.800174996
#           25%: -87.72499244275
#           50%: -87.685233078
#           75%: -87.65891481025
#           95%: -87.644545209
#           99%: -87.644545209
#         99.9%: -87.644545209
#
#     mean: -87.6973696417778
#     std: 0.05125709218559426
#     variance: 0.0026272894993225084
#     skewness: -0.8175649306454071
#     kurtosis: -0.8129192475091398
#
# ColumnProfile
#     name: Location
#     type: FieldType.STRING
#
#     min:
#     max: (42.008124017, -87.65955018)
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1.0

# %% [markdown]
# We can see there are latitude and longitude columns present in this dataset. By definition, these are constrained to specific ranges of values. We can assert that this is indeed the case so that if any records come through with invalid values, we detect them.

# %%
from azureml.dataprep import f_and, value

df = df.assert_value('Latitude', f_and(value <= 90, value >= -90), error_code='InvalidLatitude')
df = df.assert_value('Longitude', f_and(value <= 180, value >= -180), error_code='InvalidLongitude')
df.keep_columns(['Latitude', 'Longitude']).get_profile()
# Out:
# ColumnProfile
#     name: Latitude
#     type: FieldType.DECIMAL
#
#     min: 41.6793109
#     max: 42.008124017
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 1.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 41.6793109
#            1%: 41.722618652799994
#            5%: 41.6793109
#           25%: 41.81602052575
#           50%: 41.885610142
#           75%: 41.9709022135
#           95%: 42.008124017
#           99%: 42.008124017
#         99.9%: 42.008124017
#
#     mean: 41.87661278344444
#     std: 0.10364520556300645
#     variance: 0.010742328636197864
#     skewness: -0.4504133511718018
#     kurtosis: -1.027551479452864
#
# ColumnProfile
#     name: Longitude
#     type: FieldType.DECIMAL
#
#     min: -87.800174996
#     max: -87.644545209
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 1.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: -87.800174996
#            1%: -87.7820583592
#            5%: -87.800174996
#           25%: -87.72499244275
#           50%: -87.685233078
#           75%: -87.65891481025
#           95%: -87.644545209
#           99%: -87.644545209
#         99.9%: -87.644545209
#
#     mean: -87.6973696417778
#     std: 0.05125709218559426
#     variance: 0.0026272894993225084
#     skewness: -0.8175649306454071
#     kurtosis: -0.8129192475091398

# %% [markdown]
# Any assertion failures are represented as Errors in the resulting dataset. From the profile above, you can see that the Error Count for both of these columns is 1. We can use a filter to retrieve the error and see what value caused the assertion to fail.

# %%
from azureml.dataprep import col

error_df = df.filter(col('Latitude').is_error())
error = error_df.head(10)['Latitude'][0]
print(error.originalValue)
# Out:
# None

# %% [markdown]
# Our assertion failed because we were not removing missing values from our data. At this point, we have two options: we can go back and edit our code to avoid this error in the first place or we can resolve it now. In this case, we will just filter these out.

# %%
from azureml.dataprep import f_not, LocalFileOutput
clean_df = df.filter(f_not(col('Latitude').is_error()))
clean_df.get_profile()
# Out:
# ColumnProfile
#     name: ID
#     type: FieldType.DECIMAL
#
#     min: 10139697.0
#     max: 10140868.0
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 10139697.0
#            1%: 10139707.0
#            5%: 10139697.0
#           25%: 10139752.0
#           50%: 10139776.0
#           75%: 10140406.75
#           95%: 10140868.0
#           99%: 10140868.0
#         99.9%: 10140868.0
#
#     mean: 10140039.22222222
#     std: 427.7168390932695
#     variance: 182941.69444393783
#     skewness: 0.8040339784011078
#     kurtosis: -1.1193253326316737
#
# ColumnProfile
#     name: Case Number
#     type: FieldType.STRING
#
#     min: HY329177
#     max: HY330421
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Date
#     type: FieldType.STRING
#
#     min: 07/05/2015 10:10:00 PM
#     max: 07/05/2015 11:50:00 PM
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Block
#     type: FieldType.STRING
#
#     min: 011XX W MORSE AVE
#     max: 118XX S PEORIA ST
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: IUCR
#     type: FieldType.DECIMAL
#
#     min: 460.0
#     max: 1811.0
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 460.0
#            1%: 520.0
#            5%: 460.0
#           25%: 767.5
#           50%: 1020.0
#           75%: 1320.0
#           95%: 1811.0
#           99%: 1811.0
#         99.9%: 1811.0
#
#     mean: 1066.7777777777778
#     std: 418.3132133275788
#     variance: 174985.94444444447
#     skewness: 0.18619665604951927
#     kurtosis: -1.1796853443292066
#
# ColumnProfile
#     name: Primary Type
#     type: FieldType.STRING
#
#     min: ARSON
#     max: THEFT
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Description
#     type: FieldType.STRING
#
#     min: $500 AND UNDER
#     max: TO VEHICLE
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Location Description
#     type: FieldType.STRING
#
#     min: ALLEY
#     max: VEHICLE NON-COMMERCIAL
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Arrest
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Domestic
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Beat
#     type: FieldType.DECIMAL
#
#     min: 524.0
#     max: 2431.0
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 524.0
#            1%: 644.0
#            5%: 524.0
#           25%: 889.25
#           50%: 1215.0
#           75%: 1717.75
#           95%: 2431.0
#           99%: 2431.0
#         99.9%: 2431.0
#
#     mean: 1344.6666666666667
#     std: 613.7485234198124
#     variance: 376687.24999999994
#     skewness: 0.3945746305479658
#     kurtosis: -1.2804190256415895
#
# ColumnProfile
#     name: District
#     type: FieldType.DECIMAL
#
#     min: 5.0
#     max: 24.0
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 5.0
#            1%: 6.2
#            5%: 5.0
#           25%: 8.75
#           50%: 12.0
#           75%: 17.0
#           95%: 24.0
#           99%: 24.0
#         99.9%: 24.0
#
#     mean: 13.222222222222221
#     std: 6.098724821177329
#     variance: 37.19444444444444
#     skewness: 0.3828128522782998
#     kurtosis: -1.2800261778487807
#
# ColumnProfile
#     name: Ward
#     type: FieldType.DECIMAL
#
#     min: 12.0
#     max: 49.0
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 12.0
#            1%: 13.6
#            5%: 12.0
#           25%: 22.0
#           50%: 34.0
#           75%: 42.25
#           95%: 49.0
#           99%: 49.0
#         99.9%: 49.0
#
#     mean: 31.77777777777778
#     std: 12.940032629187781
#     variance: 167.44444444444446
#     skewness: -0.170295233461875
#     kurtosis: -1.5890111834924123
#
# ColumnProfile
#     name: Community Area
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 63.0
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1.0
#            1%: 1.8000000000000003
#            5%: 1.0
#           25%: 8.25
#           50%: 28.0
#           75%: 54.25
#           95%: 63.0
#           99%: 63.0
#         99.9%: 63.0
#
#     mean: 30.0
#     std: 23.4574082114798
#     variance: 550.25
#     skewness: 0.15365816205366958
#     kurtosis: -1.7230043278599128
#
# ColumnProfile
#     name: FBI Code
#     type: FieldType.STRING
#
#     min: 05
#     max: 18
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: X Coordinate
#     type: FieldType.DECIMAL
#
#     min: 1129230.0
#     max: 1172409.0
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1129230.0
#            1%: 1134226.4
#            5%: 1129230.0
#           25%: 1149945.5
#           50%: 1160997.0
#           75%: 1167630.75
#           95%: 1172409.0
#           99%: 1172409.0
#         99.9%: 1172409.0
#
#     mean: 1157453.7777777778
#     std: 14052.038898125935
#     variance: 197459797.19444433
#     skewness: -0.8167695241975886
#     kurtosis: -0.7955776867289264
#
# ColumnProfile
#     name: Y Coordinate
#     type: FieldType.DECIMAL
#
#     min: 1826485.0
#     max: 1946271.0
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1826485.0
#            1%: 1842231.4
#            5%: 1826485.0
#           25%: 1876206.25
#           50%: 1901632.0
#           75%: 1932624.25
#           95%: 1946271.0
#           99%: 1946271.0
#         99.9%: 1946271.0
#
#     mean: 1898273.3333333333
#     std: 37733.23942825477
#     variance: 1423797357.7500005
#     skewness: -0.4481360090688111
#     kurtosis: -1.028783137057662
#
# ColumnProfile
#     name: Year
#     type: FieldType.DECIMAL
#
#     min: 2015.0
#     max: 2015.0
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 2015.0
#            1%: 2015.0
#            5%: 2015.0
#           25%: 2015.0
#           50%: 2015.0
#           75%: 2015.0
#           95%: 2015.0
#           99%: 2015.0
#         99.9%: 2015.0
#
#     mean: 2015.0
#     std: 0.0
#     variance: 0.0
#     skewness: nan
#     kurtosis: nan
#
# ColumnProfile
#     name: Updated On
#     type: FieldType.STRING
#
#     min: 07/12/2015 12:42:46 PM
#     max: 07/12/2015 12:42:46 PM
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: Latitude
#     type: FieldType.DECIMAL
#
#     min: 41.6793109
#     max: 42.008124017
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 41.6793109
#            1%: 41.722618652799994
#            5%: 41.6793109
#           25%: 41.81602052575
#           50%: 41.885610142
#           75%: 41.9709022135
#           95%: 42.008124017
#           99%: 42.008124017
#         99.9%: 42.008124017
#
#     mean: 41.87661278344444
#     std: 0.10364520556300645
#     variance: 0.010742328636197864
#     skewness: -0.4504133511718018
#     kurtosis: -1.027551479452864
#
# ColumnProfile
#     name: Longitude
#     type: FieldType.DECIMAL
#
#     min: -87.800174996
#     max: -87.644545209
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: -87.800174996
#            1%: -87.7820583592
#            5%: -87.800174996
#           25%: -87.72499244275
#           50%: -87.685233078
#           75%: -87.65891481025
#           95%: -87.644545209
#           99%: -87.644545209
#         99.9%: -87.644545209
#
#     mean: -87.6973696417778
#     std: 0.05125709218559426
#     variance: 0.0026272894993225084
#     skewness: -0.8175649306454071
#     kurtosis: -0.8129192475091398
#
# ColumnProfile
#     name: Location
#     type: FieldType.STRING
#
#     min: (41.6793109, -87.644545209)
#     max: (42.008124017, -87.65955018)
#     count: 9.0
#     missing_count: 0.0
#     not_missing_count: 9.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
