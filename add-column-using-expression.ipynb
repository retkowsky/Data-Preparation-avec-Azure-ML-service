# %% [markdown]
# # Add Column using Expression
# Copyright (c) Microsoft Corporation. All rights reserved.<br>
# Licensed under the MIT License.

# %% [markdown]
# DataPrep has the ability to add a new column to data using an expression to calculate the value from existing columns. In this case, we will attempt to add additional columns to the input data.

# %%
# !pip install azureml-sdk
# Out:
# Collecting azureml-sdk
#   Downloading https://files.pythonhosted.org/packages/02/2e/569dfddc1232196991da94ca742a992828f39f805ed922e737a321a6e026/azureml_sdk-1.0.6-py3-none-any.whl
# Collecting azureml-train==1.0.6.* (from azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/28/62/4f919e986aec7357728320c9d76cb4e2c0c56f95b5b9bea058932dae5b3d/azureml_train-1.0.6-py3-none-any.whl
# Collecting azureml-core==1.0.6.* (from azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/e9/6c/e15677f2e09c34799a61b6146418f93402c93913f538c64665ff69371e64/azureml_core-1.0.6-py2.py3-none-any.whl (658kB)
#     100% |████████████████████████████████| 665kB 13.2MB/s ta 0:00:01
# Collecting azureml-pipeline==1.0.6.* (from azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/f5/f5/b9dfe817ea791964aabd77a78c4f85a586357f5413c3af23a81800960b33/azureml_pipeline-1.0.6-py3-none-any.whl
# Collecting azureml-train-core==1.0.6.* (from azureml-train==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/a1/f7/a07d6b9cf3fddcd2352a408be117018eb8dd27a78d0dc34471f8ffa70b0b/azureml_train_core-1.0.6-py3-none-any.whl (63kB)
#     100% |████████████████████████████████| 71kB 16.2MB/s ta 0:00:01
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/60/c7/99b33c53cf3f20a97a4c4bfd3ab66dcc93d99da0a97cc9597aa36ae6bb62/cryptography-2.4.2-cp34-abi3-manylinux1_x86_64.whl (2.1MB)
#     100% |████████████████████████████████| 2.1MB 7.1MB/s eta 0:00:01
# Requirement already satisfied: contextlib2 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azureml-core==1.0.6.*->azureml-sdk) (0.5.3)
# Collecting azure-cli-core>=2.0.38 (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/4b/4f/67936d40a4a602259549b2af62eed9bb551619ebaa32f59c7ff3f283ad8e/azure_cli_core-2.0.54-py2.py3-none-any.whl (107kB)
#     100% |████████████████████████████████| 112kB 23.5MB/s ta 0:00:01
# Requirement already satisfied: azure-storage-blob>=1.1.0 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azureml-core==1.0.6.*->azureml-sdk) (1.4.0)
# Collecting azure-graphrbac>=0.40.0 (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/da/a8/3d3d6fe8458b2b07bad10195c79928ea9ba87b5cc0c08903b387dd27c6f0/azure_graphrbac-0.53.0-py2.py3-none-any.whl (108kB)
#     100% |████████████████████████████████| 112kB 19.4MB/s ta 0:00:01
# Collecting msrest>=0.5.1 (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/d5/40/70e545b7a5b0509273c6fe981118fb64e389fe013504b1c22a24fec4d1d9/msrest-0.6.2-py2.py3-none-any.whl (81kB)
#     100% |████████████████████████████████| 81kB 19.0MB/s ta 0:00:01
# Collecting azure-cli-profile>=2.0.26 (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/c2/d3/fdc722a1b61857250a76027d6d73a50182c6d85132ddd65600a8993574ce/azure_cli_profile-2.1.2-py2.py3-none-any.whl
# Collecting msrestazure>=0.4.33 (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/46/ba/7870308e3d3b4b3956880eed2df20669a5690436793e6fc1442c8b73e01c/msrestazure-0.6.0-py2.py3-none-any.whl
# Collecting ruamel.yaml<=0.15.51,>=0.15.35 (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/45/34/4818c6936fbe2a8dbda9430eb50d7e2e035e24db0ee5b232c68c54cb0c44/ruamel.yaml-0.15.51-cp35-cp35m-manylinux1_x86_64.whl (620kB)
#     100% |████████████████████████████████| 624kB 18.0MB/s ta 0:00:01
# Collecting docker (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/e1/58/938fbc7acd98302ca4872f5eab8ab811498e342ab5aec0c1609f22e0aeda/docker-3.6.0-py2.py3-none-any.whl (131kB)
#     100% |████████████████████████████████| 133kB 23.9MB/s ta 0:00:01
# Requirement already satisfied: pytz in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azureml-core==1.0.6.*->azureml-sdk) (2016.6.1)
# Collecting jsonpickle (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/ca/ce/97404d5aeb58e6155c216825c81b50f6eca8a5345c582317ae48391878f8/jsonpickle-1.0-py2.py3-none-any.whl
# Collecting azure-mgmt-authorization>=0.40.0 (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/a1/71/9a20913e92771b3c23564f1bea54d376d09fb30a75585087c70b769d75c8/azure_mgmt_authorization-0.51.1-py2.py3-none-any.whl (111kB)
#     100% |████████████████████████████████| 112kB 22.2MB/s ta 0:00:01
# Collecting backports.tempfile (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/b4/5c/077f910632476281428fe254807952eb47ca78e720d059a46178c541e669/backports.tempfile-1.0-py2.py3-none-any.whl
# Collecting pathspec (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/84/2a/bfee636b1e2f7d6e30dd74f49201ccfa5c3cf322d44929ecc6c137c486c5/pathspec-0.5.9.tar.gz
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azureml-core==1.0.6.*->azureml-sdk) (2.7.5)
# Collecting azure-mgmt-containerregistry>=2.0.0 (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/fd/70/314fd97e8ea1d324f1f692cd06aa306f79e21500ba8248059dd3483ba14a/azure_mgmt_containerregistry-2.5.0-py2.py3-none-any.whl (494kB)
#     100% |████████████████████████████████| 501kB 11.6MB/s ta 0:00:01
# Requirement already satisfied: azure-common>=1.1.12 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azureml-core==1.0.6.*->azureml-sdk) (1.1.16)
# Collecting requests>=2.19.1 (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/7d/e3/20f3d364d6c8e5d2353c72a67778eb189176f08e873c9900e10c0287b84b/requests-2.21.0-py2.py3-none-any.whl (57kB)
#     100% |████████████████████████████████| 61kB 17.1MB/s ta 0:00:01
# Collecting azure-mgmt-resource>=1.2.1 (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/2b/26/c0cb69dfac2e5b7125db034045b8bcf937cf1e8d3df2009a87c33d0959f5/azure_mgmt_resource-2.0.0-py2.py3-none-any.whl (698kB)
#     100% |████████████████████████████████| 706kB 11.0MB/s ta 0:00:01
# Requirement already satisfied: six>=1.11.0 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azureml-core==1.0.6.*->azureml-sdk) (1.11.0)
# Collecting ndg-httpsclient (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/fb/67/c2f508c00ed2a6911541494504b7cac16fe0b0473912568df65fd1801132/ndg_httpsclient-0.5.1-py3-none-any.whl
# Collecting urllib3<1.24,>=1.23 (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/bd/c9/6fdd990019071a4a32a5e7cb78a1d92c53851ef4f56f62a3486e6a7d8ffb/urllib3-1.23-py2.py3-none-any.whl (133kB)
#     100% |████████████████████████████████| 143kB 23.1MB/s ta 0:00:01
# Requirement already satisfied: PyJWT in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azureml-core==1.0.6.*->azureml-sdk) (1.7.1)
# Collecting azure-mgmt-storage>=1.5.0 (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/e8/d9/496b29857a252bc3fcc4bbda069c0eb64b537c8e8f7e342abb4053ba920f/azure_mgmt_storage-3.1.0-py2.py3-none-any.whl (696kB)
#     100% |████████████████████████████████| 706kB 14.9MB/s ta 0:00:01
# Collecting azure-storage-nspkg>=3.0.0 (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/ba/f6/054ace7b01c6c21b3b95a83c3997f7d6539d939a2c08c4f27f779128a030/azure_storage_nspkg-3.1.0-py2.py3-none-any.whl
# Collecting azure-mgmt-keyvault>=0.40.0 (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/49/de/0d69aedae7c5f6428314640b65947203ab80409c12b5d4e66fb5b7a4182e/azure_mgmt_keyvault-1.1.0-py2.py3-none-any.whl (111kB)
#     100% |████████████████████████████████| 112kB 22.3MB/s ta 0:00:01
# Requirement already satisfied: azure-storage-common>=1.1.0 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azureml-core==1.0.6.*->azureml-sdk) (1.4.0)
# Collecting SecretStorage<3.0.0 (from azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/a5/a5/0830cfe34a4cfd0d1c3c8b614ede1edb2aaf999091ac8548dd19cb352e79/SecretStorage-2.3.1.tar.gz
# Collecting azureml-pipeline-core==1.0.6.* (from azureml-pipeline==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/71/06/20e03dc6f1164aac74a1bc7587527c98cc12295aa98b39aea936f722638e/azureml_pipeline_core-1.0.6-py3-none-any.whl (127kB)
#     100% |████████████████████████████████| 133kB 17.6MB/s ta 0:00:01
# Collecting azureml-pipeline-steps==1.0.6.* (from azureml-pipeline==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/2e/6c/c28a41a5a83e5699eb14bf56a8d9dd8045bfe49726019790f1fddd8b5468/azureml_pipeline_steps-1.0.6-py3-none-any.whl
# Collecting azureml-train-restclients-hyperdrive==1.0.6.* (from azureml-train-core==1.0.6.*->azureml-train==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/31/78/7265eb9d06502bbe5bb7795b538dcd1c94b1e73efcc6e1ec6e6b5a425165/azureml_train_restclients_hyperdrive-1.0.6-py3-none-any.whl
# Collecting azureml-telemetry==1.0.6.* (from azureml-train-core==1.0.6.*->azureml-train==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/b2/03/80693f917ef4a5167ec120db2fa1837a6da757f064ea35f0285e429ebdbc/azureml_telemetry-1.0.6-py3-none-any.whl
# Requirement already satisfied: cffi!=1.11.3,>=1.7 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.6.*->azureml-sdk) (1.7.0)
# Requirement already satisfied: idna>=2.1 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.6.*->azureml-sdk) (2.1)
# Requirement already satisfied: asn1crypto>=0.21.0 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.6.*->azureml-sdk) (0.24.0)
# Collecting knack==0.5.1 (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/27/46/0a6d7471efcc519e392640f6933c0f644bbf602971e64797108292cb3623/knack-0.5.1-py2.py3-none-any.whl (50kB)
#     100% |████████████████████████████████| 51kB 18.4MB/s ta 0:00:01
# Requirement already satisfied: adal>=1.2.0 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk) (1.2.0)
# Collecting antlr4-python3-runtime; python_version >= "3.0" (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/29/14/8ac135ec7cc9db3f768e2d032776718c6b23f74e63543f0974b4873500b2/antlr4-python3-runtime-4.7.2.tar.gz (112kB)
#     100% |████████████████████████████████| 112kB 23.9MB/s ta 0:00:01
# Requirement already satisfied: pip in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk) (18.1)
# Collecting azure-cli-telemetry (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/71/4c/da5ebe9300ecdc850031372f81229383c46a70e83dee8e77f58aa6fd0546/azure_cli_telemetry-1.0.0-py2.py3-none-any.whl
# Collecting azure-cli-nspkg>=2.0.0 (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/a7/85/601ef6484bf7a722daa76a4383c4ccfd4980b74ed6c2895392f53ed210d5/azure_cli_nspkg-3.0.3-py2.py3-none-any.whl
# Collecting paramiko>=2.0.8 (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/cf/ae/94e70d49044ccc234bfdba20114fa947d7ba6eb68a2e452d89b920e62227/paramiko-2.4.2-py2.py3-none-any.whl (193kB)
#     100% |████████████████████████████████| 194kB 22.8MB/s ta 0:00:01
# Collecting argcomplete>=1.8.0 (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/31/88/ba8d8684a8a27749250c66ff7c2b408fdbc29b50da61200338ff9b2607bf/argcomplete-1.9.4-py2.py3-none-any.whl
# Collecting futures (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/cc/26/b61e3a4eb50653e8a7339d84eeaa46d1e93b92951978873c220ae64d0733/futures-3.1.1.tar.gz
# Requirement already satisfied: pyopenssl>=17.1.0 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk) (17.2.0)
# Requirement already satisfied: pygments in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk) (2.1.3)
# Requirement already satisfied: colorama>=0.3.9 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk) (0.3.9)
# Requirement already satisfied: jmespath in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk) (0.9.3)
# Collecting humanfriendly>=4.7 (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/79/1e/13d96248e3fcaa7777b61fa889feab44865c85e524bbd667acfa0d8b66e3/humanfriendly-4.17-py2.py3-none-any.whl (72kB)
#     100% |████████████████████████████████| 81kB 21.3MB/s ta 0:00:01
# Requirement already satisfied: tabulate<=0.8.2,>=0.7.7 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk) (0.8.2)
# Requirement already satisfied: pyyaml~=3.13 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk) (3.13)
# Collecting wheel==0.30.0 (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/0c/80/16a85b47702a1f47a63c104c91abdd0a6704ee8ae3b4ce4afc49bc39f9d9/wheel-0.30.0-py2.py3-none-any.whl (49kB)
#     100% |████████████████████████████████| 51kB 13.4MB/s ta 0:00:01
# Collecting isodate>=0.6.0 (from msrest>=0.5.1->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
#     100% |████████████████████████████████| 51kB 18.4MB/s ta 0:00:01
# Collecting certifi>=2017.4.17 (from msrest>=0.5.1->azureml-core==1.0.6.*->azureml-sdk)
#   Using cached https://files.pythonhosted.org/packages/9f/e0/accfc1b56b57e9750eba272e24c4dddeac86852c2bebd1236674d7887e8a/certifi-2018.11.29-py2.py3-none-any.whl
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.5.1->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/94/e7/c250d122992e1561690d9c0f7856dadb79d61fd4bdd0e598087dce607f6c/requests_oauthlib-1.0.0-py2.py3-none-any.whl
# Collecting azure-cli-command-modules-nspkg>=2.0.0 (from azure-cli-profile>=2.0.26->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/e6/c9/cdeeeabc550848e2a07caa66cba28aa057d23b6feaa824ceafd32c3f2226/azure_cli_command_modules_nspkg-2.0.2-py2.py3-none-any.whl
# Requirement already satisfied: docker-pycreds>=0.3.0 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from docker->azureml-core==1.0.6.*->azureml-sdk) (0.4.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from docker->azureml-core==1.0.6.*->azureml-sdk) (0.54.0)
# Collecting backports.weakref (from backports.tempfile->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/88/ec/f598b633c3d5ffe267aaada57d961c94fdfa183c5c3ebda2b6d151943db6/backports.weakref-1.0.post1-py2.py3-none-any.whl
# Collecting chardet<3.1.0,>=3.0.2 (from requests>=2.19.1->azureml-core==1.0.6.*->azureml-sdk)
#   Using cached https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl
# Collecting azure-mgmt-nspkg>=2.0.0 (from azure-mgmt-resource>=1.2.1->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/b3/c2/af4b47845f27dc7d206ed4908b9e580f8bc94a4b2f3956a0d87c40719d90/azure_mgmt_nspkg-3.0.2-py3-none-any.whl
# Requirement already satisfied: pyasn1>=0.1.1 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from ndg-httpsclient->azureml-core==1.0.6.*->azureml-sdk) (0.1.9)
# Requirement already satisfied: azure-nspkg>=2.0.0 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azure-storage-nspkg>=3.0.0->azureml-core==1.0.6.*->azureml-sdk) (3.0.2)
# Collecting applicationinsights (from azureml-telemetry==1.0.6.*->azureml-train-core==1.0.6.*->azureml-train==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/e3/c8/7848a0dd85158930b859eb8be1e38fc76a91f0a040d491723ebb356d7358/applicationinsights-0.11.7-py2.py3-none-any.whl (56kB)
#     100% |████████████████████████████████| 61kB 17.2MB/s ta 0:00:01
# Requirement already satisfied: pycparser in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from cffi!=1.11.3,>=1.7->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.6.*->azureml-sdk) (2.14)
# Collecting portalocker==1.2.1 (from azure-cli-telemetry->azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/57/41/05e79e5516db1cc0c967b3202388cde729f871c871b0a07bf24ff11adfcf/portalocker-1.2.1-py2.py3-none-any.whl
# Collecting bcrypt>=3.1.3 (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/31/4b/4057d0716e7170c29ff12e19791eb6037422620835e4a58a01d4790e56d1/bcrypt-3.1.5-cp34-abi3-manylinux1_x86_64.whl (55kB)
#     100% |████████████████████████████████| 61kB 17.9MB/s ta 0:00:01
# Collecting pynacl>=1.0.1 (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/27/15/2cd0a203f318c2240b42cd9dd13c931ddd61067809fee3479f44f086103e/PyNaCl-1.3.0-cp34-abi3-manylinux1_x86_64.whl (759kB)
#     100% |████████████████████████████████| 768kB 19.2MB/s ta 0:00:01
# Collecting oauthlib>=0.6.2 (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core==1.0.6.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/e6/d1/ddd9cfea3e736399b97ded5c2dd62d1322adef4a72d816f1ed1049d6a179/oauthlib-2.1.0-py2.py3-none-any.whl (121kB)
#     100% |████████████████████████████████| 122kB 25.7MB/s ta 0:00:01
# Building wheels for collected packages: pathspec, SecretStorage, antlr4-python3-runtime, futures
#   Running setup.py bdist_wheel for pathspec ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/45/cb/7e/ce6e6062c69446e39e328170524ca8213498bc66a74c6a210b
#   Running setup.py bdist_wheel for SecretStorage ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/4e/5b/1b/be8c8a830a0243af85b2946a0aece2c6743d7f7f946977ed67
#   Running setup.py bdist_wheel for antlr4-python3-runtime ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/03/65/47/b6700d23b7529a49513f7601b4f96174a4fa9efdbec03e7ea3
#   Running setup.py bdist_wheel for futures ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/f3/f9/c7/4fbf1faa6038faf183f6e3ea61f17a5f7eea5ab9a1dd7753fd
# Successfully built pathspec SecretStorage antlr4-python3-runtime futures
# requests 2.21.0 has requirement idna<2.9,>=2.5, but you'll have idna 2.1 which is incompatible.
# Installing collected packages: certifi, urllib3, azureml-train-restclients-hyperdrive, cryptography, argcomplete, knack, antlr4-python3-runtime, isodate, oauthlib, chardet, requests, requests-oauthlib, msrest, azure-cli-nspkg, portalocker, applicationinsights, azure-cli-telemetry, msrestazure, azure-mgmt-nspkg, azure-mgmt-resource, bcrypt, pynacl, paramiko, futures, humanfriendly, wheel, azure-cli-core, azure-graphrbac, azure-cli-command-modules-nspkg, azure-cli-profile, ruamel.yaml, docker, jsonpickle, azure-mgmt-authorization, backports.weakref, backports.tempfile, pathspec, azure-mgmt-containerregistry, ndg-httpsclient, azure-mgmt-storage, azure-storage-nspkg, azure-mgmt-keyvault, SecretStorage, azureml-core, azureml-telemetry, azureml-train-core, azureml-train, azureml-pipeline-core, azureml-pipeline-steps, azureml-pipeline, azureml-sdk
#   Found existing installation: urllib3 1.24.1
#     Uninstalling urllib3-1.24.1:
#       Successfully uninstalled urllib3-1.24.1
#   Found existing installation: cryptography 2.0.3
#     Uninstalling cryptography-2.0.3:
#       Successfully uninstalled cryptography-2.0.3
#   Found existing installation: argcomplete 1.0.0
#     Uninstalling argcomplete-1.0.0:
#       Successfully uninstalled argcomplete-1.0.0
#   Found existing installation: requests 2.14.2
#     Uninstalling requests-2.14.2:
#       Successfully uninstalled requests-2.14.2
#   Found existing installation: wheel 0.29.0
#     Uninstalling wheel-0.29.0:
#       Successfully uninstalled wheel-0.29.0
# Successfully installed SecretStorage-2.3.1 antlr4-python3-runtime-4.7.2 applicationinsights-0.11.7 argcomplete-1.9.4 azure-cli-command-modules-nspkg-2.0.2 azure-cli-core-2.0.54 azure-cli-nspkg-3.0.3 azure-cli-profile-2.1.2 azure-cli-telemetry-1.0.0 azure-graphrbac-0.53.0 azure-mgmt-authorization-0.51.1 azure-mgmt-containerregistry-2.5.0 azure-mgmt-keyvault-1.1.0 azure-mgmt-nspkg-3.0.2 azure-mgmt-resource-2.0.0 azure-mgmt-storage-3.1.0 azure-storage-nspkg-3.1.0 azureml-core-1.0.6 azureml-pipeline-1.0.6 azureml-pipeline-core-1.0.6 azureml-pipeline-steps-1.0.6 azureml-sdk-1.0.6 azureml-telemetry-1.0.6 azureml-train-1.0.6 azureml-train-core-1.0.6 azureml-train-restclients-hyperdrive-1.0.6 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.1.5 certifi-2018.11.29 chardet-3.0.4 cryptography-2.4.2 docker-3.6.0 futures-3.1.1 humanfriendly-4.17 isodate-0.6.0 jsonpickle-1.0 knack-0.5.1 msrest-0.6.2 msrestazure-0.6.0 ndg-httpsclient-0.5.1 oauthlib-2.1.0 paramiko-2.4.2 pathspec-0.5.9 portalocker-1.2.1 pynacl-1.3.0 requests-2.21.0 requests-oauthlib-1.0.0 ruamel.yaml-0.15.51 urllib3-1.23 wheel-0.30.0

# %%
# !pip install --upgrade azureml-dataprep
# Out:
# Collecting azureml-dataprep
#   Downloading https://files.pythonhosted.org/packages/ca/b4/c56a28714411318b32bc9c8ceea12f7f1ccc2b953c60cd91d5fb5715c42b/azureml_dataprep-1.0.4-py3-none-any.whl (24.6MB)
#     100% |████████████████████████████████| 24.6MB 148kB/s eta 0:00:01   12% |████                            | 3.0MB 23.4MB/s eta 0:00:01
# Collecting dotnetcore2==2.1.7 (from azureml-dataprep)
#   Downloading https://files.pythonhosted.org/packages/5e/ad/563e291f291ddae9967fc6347b5240e5ee5fdb173c33e0780c30ca8cd4c2/dotnetcore2-2.1.7-py3-none-manylinux1_x86_64.whl (28.7MB)
#     100% |████████████████████████████████| 28.7MB 142kB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azureml-dataprep) (1.15.4)
# Collecting azureml-dataprep-native<12.0.0,>=11.2.0 (from azureml-dataprep)
#   Downloading https://files.pythonhosted.org/packages/82/89/1d32da745dab80e08314b2af1bf2c954b3dce01527f275533a41c812b2e3/azureml_dataprep_native-11.2.0-cp35-cp35m-manylinux1_x86_64.whl (1.3MB)
#     100% |████████████████████████████████| 1.4MB 9.3MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: pandas>=0.19.2 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from azureml-dataprep) (0.19.2)
# Collecting distro>=1.2.0 (from dotnetcore2==2.1.7->azureml-dataprep)
#   Downloading https://files.pythonhosted.org/packages/f6/b1/ba5a96bccd3496241d8908164b9502a129156443cdd5acbdbf04a90b7a09/distro-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: python-dateutil>=2 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from pandas>=0.19.2->azureml-dataprep) (2.7.5)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from pandas>=0.19.2->azureml-dataprep) (2016.6.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from python-dateutil>=2->pandas>=0.19.2->azureml-dataprep) (1.11.0)
# Installing collected packages: distro, dotnetcore2, azureml-dataprep-native, azureml-dataprep
# Successfully installed azureml-dataprep-1.0.4 azureml-dataprep-native-11.2.0 distro-1.3.0 dotnetcore2-2.1.7

# %%
import azureml.dataprep as dprep

# %%
# loading data
dataflow = dprep.read_csv(path=r'data\crime0-10.csv')
dataflow.head(5)
# Out:
#          ID Case Number                    Date                Block  IUCR  \
# 0  10140490    HY329907  07/05/2015 11:50:00 PM  050XX N NEWLAND AVE  0820
# 1  10139776    HY329265  07/05/2015 11:30:00 PM    011XX W MORSE AVE  0460
# 2  10140270    HY329253  07/05/2015 11:20:00 PM    121XX S FRONT AVE  0486
# 3  10139885    HY329308  07/05/2015 11:19:00 PM  051XX W DIVISION ST  0610
# 4  10140379    HY329556  07/05/2015 11:00:00 PM      012XX W LAKE ST  0930
#
#           Primary Type                 Description Location Description  \
# 0                THEFT              $500 AND UNDER               STREET
# 1              BATTERY                      SIMPLE               STREET
# 2              BATTERY     DOMESTIC BATTERY SIMPLE               STREET
# 3             BURGLARY              FORCIBLE ENTRY   SMALL RETAIL STORE
# 4  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE               STREET
#
#   Arrest Domestic              ...               Ward Community Area FBI Code  \
# 0  false    false              ...                 41             10       06
# 1  false     true              ...                 49              1      08B
# 2  false     true              ...                  9             53      08B
# 3  false    false              ...                 37             25       05
# 4  false    false              ...                 27             28       07
#
#   X Coordinate Y Coordinate  Year              Updated On      Latitude  \
# 0      1129230      1933315  2015  07/12/2015 12:42:46 PM  41.973309466
# 1      1167370      1946271  2015  07/12/2015 12:42:46 PM  42.008124017
# 2                            2015  07/12/2015 12:42:46 PM
# 3      1141721      1907465  2015  07/12/2015 12:42:46 PM  41.902152027
# 4      1168413      1901632  2015  07/12/2015 12:42:46 PM  41.885610142
#
#        Longitude                       Location
# 0  -87.800174996  (41.973309466, -87.800174996)
# 1   -87.65955018   (42.008124017, -87.65955018)
# 2
# 3  -87.754883404  (41.902152027, -87.754883404)
# 4  -87.657008701  (41.885610142, -87.657008701)
#
# [5 rows x 22 columns]

# %% [markdown]
# #### `substring(start, length)`
# Add a new column _Case Category_ using the `substring(start, length)` expression to extract the prefix from the _Case Number_ column.

# %%
substring_expression = dprep.col('Case Number').substring(0, 2)
case_category = dataflow.add_column(new_column_name='Case Category',
                                    prior_column='Case Number',
                                    expression=substring_expression)
case_category.head(5)
# Out:
#          ID Case Number Case Category                    Date  \
# 0  10140490    HY329907            HY  07/05/2015 11:50:00 PM
# 1  10139776    HY329265            HY  07/05/2015 11:30:00 PM
# 2  10140270    HY329253            HY  07/05/2015 11:20:00 PM
# 3  10139885    HY329308            HY  07/05/2015 11:19:00 PM
# 4  10140379    HY329556            HY  07/05/2015 11:00:00 PM
#
#                  Block  IUCR         Primary Type                 Description  \
# 0  050XX N NEWLAND AVE  0820                THEFT              $500 AND UNDER
# 1    011XX W MORSE AVE  0460              BATTERY                      SIMPLE
# 2    121XX S FRONT AVE  0486              BATTERY     DOMESTIC BATTERY SIMPLE
# 3  051XX W DIVISION ST  0610             BURGLARY              FORCIBLE ENTRY
# 4      012XX W LAKE ST  0930  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE
#
#   Location Description Arrest              ...               Ward  \
# 0               STREET  false              ...                 41
# 1               STREET  false              ...                 49
# 2               STREET  false              ...                  9
# 3   SMALL RETAIL STORE  false              ...                 37
# 4               STREET  false              ...                 27
#
#   Community Area FBI Code X Coordinate Y Coordinate  Year  \
# 0             10       06      1129230      1933315  2015
# 1              1      08B      1167370      1946271  2015
# 2             53      08B                            2015
# 3             25       05      1141721      1907465  2015
# 4             28       07      1168413      1901632  2015
#
#                Updated On      Latitude      Longitude  \
# 0  07/12/2015 12:42:46 PM  41.973309466  -87.800174996
# 1  07/12/2015 12:42:46 PM  42.008124017   -87.65955018
# 2  07/12/2015 12:42:46 PM
# 3  07/12/2015 12:42:46 PM  41.902152027  -87.754883404
# 4  07/12/2015 12:42:46 PM  41.885610142  -87.657008701
#
#                         Location
# 0  (41.973309466, -87.800174996)
# 1   (42.008124017, -87.65955018)
# 2
# 3  (41.902152027, -87.754883404)
# 4  (41.885610142, -87.657008701)
#
# [5 rows x 23 columns]

# %% [markdown]
# #### `substring(start)`
# Add a new column _Case Id_ using the `substring(start)` expression to extract just the number from _Case Number_ column and convert it to numeric.

# %%
substring_expression2 = dprep.col('Case Number').substring(2)
case_id = dataflow.add_column(new_column_name='Case Id',
                              prior_column='Case Number',
                              expression=substring_expression2)
case_id = case_id.to_number('Case Id')
case_id.head(5)
# Out:
#          ID Case Number   Case Id                    Date  \
# 0  10140490    HY329907  329907.0  07/05/2015 11:50:00 PM
# 1  10139776    HY329265  329265.0  07/05/2015 11:30:00 PM
# 2  10140270    HY329253  329253.0  07/05/2015 11:20:00 PM
# 3  10139885    HY329308  329308.0  07/05/2015 11:19:00 PM
# 4  10140379    HY329556  329556.0  07/05/2015 11:00:00 PM
#
#                  Block  IUCR         Primary Type                 Description  \
# 0  050XX N NEWLAND AVE  0820                THEFT              $500 AND UNDER
# 1    011XX W MORSE AVE  0460              BATTERY                      SIMPLE
# 2    121XX S FRONT AVE  0486              BATTERY     DOMESTIC BATTERY SIMPLE
# 3  051XX W DIVISION ST  0610             BURGLARY              FORCIBLE ENTRY
# 4      012XX W LAKE ST  0930  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE
#
#   Location Description Arrest              ...               Ward  \
# 0               STREET  false              ...                 41
# 1               STREET  false              ...                 49
# 2               STREET  false              ...                  9
# 3   SMALL RETAIL STORE  false              ...                 37
# 4               STREET  false              ...                 27
#
#   Community Area FBI Code X Coordinate Y Coordinate  Year  \
# 0             10       06      1129230      1933315  2015
# 1              1      08B      1167370      1946271  2015
# 2             53      08B                            2015
# 3             25       05      1141721      1907465  2015
# 4             28       07      1168413      1901632  2015
#
#                Updated On      Latitude      Longitude  \
# 0  07/12/2015 12:42:46 PM  41.973309466  -87.800174996
# 1  07/12/2015 12:42:46 PM  42.008124017   -87.65955018
# 2  07/12/2015 12:42:46 PM
# 3  07/12/2015 12:42:46 PM  41.902152027  -87.754883404
# 4  07/12/2015 12:42:46 PM  41.885610142  -87.657008701
#
#                         Location
# 0  (41.973309466, -87.800174996)
# 1   (42.008124017, -87.65955018)
# 2
# 3  (41.902152027, -87.754883404)
# 4  (41.885610142, -87.657008701)
#
# [5 rows x 23 columns]
